# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikaarun374/ICT_DSA/blob/main/py_casestudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
account_name = "Karthika"
account_num = 123450098
balance = 2000.0
def deposit(amount):
  global balance
  if amount > 0:
    balance += amount
    print("Amount Deposited Successfully")
  else:
    print("Invaslid Deposit Amount.")
def withdraw(amount):
  global balance
  if amount <= balance:
    balance -=amount
    print("Withdrawal Successfull")
  else:
    print("Insufficient Balance")
def check_balance():
  print("Current Balance: ", balance)
while True:
  print("\n--- Bank Acount Manager---")
  print("1. Deposit")
  print("2. Withdraw")
  print("3. Check Balance")
  print("4. Exit")
  choice = int(input("Enter Your Choice: "))
  if choice ==1:
    amt = float(input("Enter Amount To Deposit: "))
    deposit(amt)
  elif choice ==2:
    amt = float(input("Enter amount To Withdraw: "))
    withdraw(amt)
  elif choice ==3:
    check_balance()
  elif choice ==4:
    print("Thank You")
    break
  else:
    print("Invalid Choice.Please Try Again")
# Out:
# --- Bank Acount Manager---
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter Your Choice: 3
# Current Balance:  2000.0
#
# --- Bank Acount Manager---
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter Your Choice: 4
# Thank You

# %%
temperatures = [30,32,28,35,31]
humidity = [60,65,70,55,68]
def avg_temperature(temp_list):
  return sum(temp_list) / len(temp_list)
def avg_humidity(hum_list):
  return sum(hum_list) / len(hum_list)
def weather_condition(avg_temp, avg_hum):
  if avg_temp > 33:
    return "Hot"
  elif avg_temp > 25 and avg_hum < 65:
    return "Sunny"
  elif avg_hum > 65:
    return "Rainy"
  else:
    return "Normal"
avg_temp = avg_temperature(temperatures)
avg_hum = avg_humidity(humidity)
condition = weather_condition(avg_temp, avg_hum)

print("Average Temperature:", avg_temp)
print("Average Humidity:", avg_hum)
print("Weather Condition:", condition)
# Out:
# Average Temperature: 31.2
# Average Humidity: 63.6
# Weather Condition: Sunny
